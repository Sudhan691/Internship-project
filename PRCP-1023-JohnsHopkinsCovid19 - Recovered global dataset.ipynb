# %% [markdown]
# ### PRCP-1023-JohnsHopkinsCovid19 - Recovered Global dataset

# %% [markdown]
# ### TASK-1: Prepare a complete data analysis report on the given data.

# %%
## Importing librries
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
## loading the data
data=pd.read_csv('time_series_covid19_recovered_global.csv')

# %%
data
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110  67.709953        0
# 1              NaN             Albania  41.153300  20.168300        0
# 2              NaN             Algeria  28.033900   1.659600        0
# 3              NaN             Andorra  42.506300   1.521800        0
# 4              NaN              Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 248            NaN  West Bank and Gaza  31.952200  35.233200        0
# 249            NaN      Western Sahara  24.215500 -12.885800        0
# 250            NaN               Yemen  15.552727  48.516388        0
# 251            NaN              Zambia -13.133897  27.849332        0
# 252            NaN            Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  9/12/20  9/13/20  \
# ...

# %% [markdown]
# ### Data preprocessing :

# %%
data =data.drop(["Province/State","Lat","Long"],axis=1).groupby('Country/Region').sum()

# %%
data
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
recovered_global=data.T

# %%
recovered_global
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 1/22/20                   0        0        0        0       0
# 1/23/20                   0        0        0        0       0
# 1/24/20                   0        0        0        0       0
# 1/25/20                   0        0        0        0       0
# 1/26/20                   0        0        0        0       0
# ...                     ...      ...      ...      ...     ...
# 9/17/20               32505     6788    34675     1054    1405
# 9/18/20               32576     6831    34818     1164    1443
# 9/19/20               32576     6888    34923     1164    1445
# 9/20/20               32576     6940    35047     1164    1445
# 9/21/20               32576     6995    35180     1199    1449
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 1/22/20                           0          0        0          0        0
# ...

# %% [markdown]
# ### Basic checks :

# %%
recovered_global.head(5)
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 1/22/20                   0        0        0        0       0
# 1/23/20                   0        0        0        0       0
# 1/24/20                   0        0        0        0       0
# 1/25/20                   0        0        0        0       0
# 1/26/20                   0        0        0        0       0
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 1/22/20                           0          0        0          0        0
# 1/23/20                           0          0        0          0        0
# 1/24/20                           0          0        0          0        0
# 1/25/20                           0          0        0          0        0
# 1/26/20                           0          0        0          0        0
#
# Country/Region  ...  United Kingdom  Uruguay  Uzbekistan  Venezuela  Vietnam  \
# ...

# %%
recovered_global.tail(5)
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 9/17/20               32505     6788    34675     1054    1405
# 9/18/20               32576     6831    34818     1164    1443
# 9/19/20               32576     6888    34923     1164    1445
# 9/20/20               32576     6940    35047     1164    1445
# 9/21/20               32576     6995    35180     1199    1449
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 9/17/20                          91     456347    42231      23852    28044
# 9/18/20                          92     467286    42369      23859    28451
# 9/19/20                          92     478077    42551      23966    28961
# 9/20/20                          92     488231    42608      24061    29229
# 9/21/20                          92     508563    42637      24155    29516
#
# Country/Region  ...  United Kingdom  Uruguay  Uzbekistan  Venezuela  Vietnam  \
# ...

# %%
recovered_global.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, 1/22/20 to 9/21/20
# Columns: 188 entries, Afghanistan to Zimbabwe
# dtypes: int64(188)
# memory usage: 368.4+ KB

# %%
recovered_global.describe()
# Out:
# Country/Region   Afghanistan      Albania       Algeria      Andorra  \
# count             244.000000   244.000000    244.000000   244.000000
# mean             9830.454918  1575.258197   9703.094262   490.750000
# std             12342.944169  1966.401353  11605.493670   383.875847
# min                 0.000000     0.000000      0.000000     0.000000
# 25%                 1.000000     2.000000     31.000000     1.000000
# 50%              1018.000000   780.000000   4341.000000   652.500000
# 75%             24080.500000  2478.000000  17079.500000   803.000000
# max             32576.000000  6995.000000  35180.000000  1199.000000
#
# Country/Region       Angola  Antigua and Barbuda      Argentina       Armenia  \
# count            244.000000           244.000000     244.000000    244.000000
# mean             234.545082            30.077869   67357.717213  11846.036885
# std              407.976682            33.769097  124431.776654  15016.421881
# ...

# %%
recovered_global.isnull().sum()
# Out:
# Country/Region
# Afghanistan           0
# Albania               0
# Algeria               0
# Andorra               0
# Angola                0
#                      ..
# West Bank and Gaza    0
# Western Sahara        0
# Yemen                 0
# Zambia                0
# Zimbabwe              0
# Length: 188, dtype: int64

# %% [markdown]
# ### We have selected main specific countries with COVID-recovered from the original dataset :

# %%
specified_columns = ["Switzerland","South Africa","India","US","China","United Arab Emirates","Pakistan"]  # Example column names

selected_data = recovered_global[specified_columns]
selected_data
# Out:
# Country/Region  Switzerland  South Africa    India       US  China  \
# 1/22/20                   0             0        0        0     28
# 1/23/20                   0             0        0        0     30
# 1/24/20                   0             0        0        0     36
# 1/25/20                   0             0        0        0     39
# 1/26/20                   0             0        0        0     49
# ...                     ...           ...      ...      ...    ...
# 9/17/20               39900        585303  4112551  2540334  85181
# 9/18/20               40500        586844  4208431  2556465  85204
# 9/19/20               40500        589434  4303043  2577446  85226
# 9/20/20               40500        590071  4396399  2590671  85239
# 9/21/20               40500        591208  4396399  2615949  85257
#
# Country/Region  United Arab Emirates  Pakistan
# 1/22/20                            0         0
# 1/23/20                            0         0
# ...

# %%
recovered_global.isnull().sum()
# Out:
# Country/Region
# Afghanistan           0
# Albania               0
# Algeria               0
# Andorra               0
# Angola                0
#                      ..
# West Bank and Gaza    0
# Western Sahara        0
# Yemen                 0
# Zambia                0
# Zimbabwe              0
# Length: 188, dtype: int64

# %% [markdown]
# ### EDA :

# %%
for j in range(1,2):   
    plt.figure(figsize=(40,8))
    for tt in selected_data.columns[(j-1)*7:j*7]:
        recovered_global = selected_data[[tt]]
        recovered_global = recovered_global[recovered_global[tt]> 0].reset_index(drop=True)
        recovered_global = recovered_global.rolling(2).mean().fillna(0)
        plt.plot([str(i) for i in recovered_global[tt].index],recovered_global[tt],marker='*',label=tt)
        
    plt.title("COUNTRY LEVEL RECOVERED CASES GROWTH CURVE")
    plt.legend()
    plt.xlabel('Day')
    plt.ylabel('Recover Cases')
    plt.show()

# %% [markdown]
# ### Autocorrelation :

# %%
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf

# Plot autocorrelation for each time series
for tt in selected_data.columns:
    recovered_global = selected_data[[tt]]
    recovered_global = recovered_global[recovered_global[tt] > 0].reset_index(drop=True)
    recovered_global = recovered_global.rolling(2).mean().fillna(0)
    
    plt.figure(figsize=(20, 10))
    plot_acf(recovered_global[tt], lags=40)
    plt.title(f"Autocorrelation for {tt}")
    plt.xlabel('Lag')
    plt.ylabel('Autocorrelation')
    plt.show()

# %% [markdown]
# ### Check for Stationarity and Differencing :

# %%
# ADfuller Test to check stationarity
from statsmodels.tsa.stattools import adfuller
import numpy as np

for tt in selected_data.columns:
    recovered_global = selected_data[[tt]]
    recovered_global = recovered_global[recovered_global[tt] > 0].reset_index(drop=True)
    recovered_global = recovered_global.rolling(2).mean().fillna(0)
    
    result = adfuller(recovered_global[tt])
    print(f'ADF Statistic for {tt}: {result[0]}')
    print(f'p-value for {tt}: {result[1]}')
# Out:
# ADF Statistic for Switzerland: -2.601630682189005
# p-value for Switzerland: 0.09266070674703808
# ADF Statistic for South Africa: -1.7969924890687945
# p-value for South Africa: 0.38195585832410484
# ADF Statistic for India: -3.541773657577533
# p-value for India: 0.006976877018717189
# ADF Statistic for US: 0.4011133004920066
# p-value for US: 0.9815365272780509
# ADF Statistic for China: -4.902386865053064
# p-value for China: 3.450319335672598e-05
# ADF Statistic for United Arab Emirates: 0.7956412179441923
# p-value for United Arab Emirates: 0.9915654823317419
# ADF Statistic for Pakistan: -1.6382473989413509
# p-value for Pakistan: 0.463176723928298

# %%
from statsmodels.graphics.tsaplots import plot_pacf

for tt in selected_data.columns:
    recovered_global = selected_data[[tt]]
    recovered_global = recovered_global[recovered_global[tt] > 0].reset_index(drop=True)
    recovered_global = recovered_global.rolling(2).mean().fillna(0)
    
    plt.figure(figsize=(20, 10))
    plot_acf(recovered_global[tt], lags=40)
    plt.title(f"ACF for {tt}")
    plt.xlabel('Lag')
    plt.ylabel('Autocorrelation')
    plt.show()

    plt.figure(figsize=(20, 10))
    plot_pacf(recovered_global[tt], lags=40)
    plt.title(f"PACF for {tt}")
    plt.xlabel('Lag')
    plt.ylabel('Partial Autocorrelation')
    plt.show()

# %% [markdown]
# ### Fit ARIMA Models and Select Best Model :

# %%
import statsmodels.api as sm

for tt in selected_data.columns:
    recovered_global = selected_data[[tt]]
    recovered_global = recovered_global[recovered_global[tt] > 0].reset_index(drop=True)
    recovered_global = recovered_global.rolling(2).mean().fillna(0)
    
    best_aic = np.inf
    best_order = None
    best_mdl = None
    
    for p in range(5):
        for d in range(2):
            for q in range(5):
                try:
                    tmp_mdl = sm.tsa.ARIMA(recovered_global[tt], order=(p, d, q)).fit()
                    tmp_aic = tmp_mdl.aic
                    if tmp_aic < best_aic:
                        best_aic = tmp_aic
                        best_order = (p, d, q)
                        best_mdl = tmp_mdl
                except:
                    continue
    
    print(f"Best ARIMA{best_order} model for {tt} with AIC: {best_aic}")
    print(best_mdl.summary())
# Out:
# C:\Users\navee\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\navee\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\navee\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\navee\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...

# %% [markdown]
# ### Model Diagnostics :

# %%
for tt in selected_data.columns:
    recovered_global = selected_data[[tt]]
    recovered_global = recovered_global[recovered_global[tt] > 0].reset_index(drop=True)
    recovered_global = recovered_global.rolling(2).mean().fillna(0)
    
    model = sm.tsa.ARIMA(recovered_global[tt], order=best_order)
    results = model.fit()
    
    residuals = results.resid
    
    plt.figure(figsize=(10, 5))
    plt.plot(residuals)
    plt.title(f'Residuals of the ARIMA model for {tt}')
    plt.show()
    
    plot_acf(residuals, lags=40)
    plt.title(f'Residuals ACF for {tt}')
    plt.show()
# Out:
# C:\Users\navee\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\navee\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# ### Task -2 Forecasting :

# %%
for tt in selected_data.columns:
    recovered_global = selected_data[[tt]]
    recovered_global = recovered_global[recovered_global[tt] > 0].reset_index(drop=True)
    recovered_global = recovered_global.rolling(2).mean().fillna(0)
    
    model = sm.tsa.ARIMA(recovered_global[tt], order=best_order)
    results = model.fit()
    
    forecast = results.forecast(steps=10)  # Example: forecast next 10 steps
    print(f"Forecast for {tt}:")
    print(forecast)
    
    plt.figure(figsize=(10, 5))
    plt.plot(recovered_global[tt], label='Observed')
    plt.plot(range(len(recovered_global), len(recovered_global) + len(forecast)), forecast, label='Forecast')
    plt.legend()
    plt.title(f'Forecast for {tt}')
    plt.show()
# Out:
# Forecast for Switzerland:
# 203    40574.144381
# 204    40699.134563
# 205    40769.739600
# 206    40819.078924
# 207    40859.706556
# 208    40896.393008
# 209    40930.962570
# 210    40964.123992
# 211    40996.163311
# 212    41027.206064
# Name: predicted_mean, dtype: float64
# C:\Users\navee\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Forecast for South Africa:
# 182    592066.925706
# 183    594012.233610
# 184    595903.179066
# 185    597741.642267
# 186    599529.404749
# 187    601268.157099
# 188    602959.505935
# 189    604604.980231
# 190    606206.037054
# 191    607764.066765
# Name: predicted_mean, dtype: float64
# Forecast for India:
# 219    4.428639e+06
# 220    4.487280e+06
# 221    4.544478e+06
# 222    4.602682e+06
# 223    4.660184e+06
# 224    4.718176e+06
# 225    4.775826e+06
# ...

# %% [markdown]
# ### Split the Data :

# %%
train_size = int(len(recovered_global) * 0.8)
train, test = recovered_global[:train_size], recovered_global[train_size:]

# %% [markdown]
# ### Fit the Model on Training Set :

# %%
model = sm.tsa.ARIMA(train, order=best_order)
fitted_model = model.fit()
# Out:
# C:\Users\navee\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# ### Make Predictions on the Test Set :

# %%
start = len(train)
end = len(train) + len(test) - 1
predictions = fitted_model.predict(start=start, end=end, typ='levels')

# %% [markdown]
# ### Calculate Accuracy Metrics :

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(test, predictions)
mse = mean_squared_error(test, predictions)
rmse = np.sqrt(mse)

print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Mean Absolute Error: 50654.84646357378
# Mean Squared Error: 3412836553.2024875
# Root Mean Squared Error: 58419.48778620442

# %% [markdown]
# ### Task3 - Based on the predictions from your ARIMA model, you can make several suggestions to the government health department of the country/region for preparation. Here are some suggestions:
#
#
# Resource Allocation: Allocate resources such as hospital beds, medical supplies, and personnel based on the forecasted number of COVID-19 cases.-
#
# Vaccine Distribution: Plan and execute the distribution of COVID-19 vaccines efficiently. Prioritize vaccination efforts based on the forecasted regions or demographic groups with the highest predicted case count-s
#
# Testing and Contact Tracing: Strengthen testing and contact tracing efforts in areas where the model predicts an increase in cases. Implement targeted testing strategies to identify and isolate infected individuals proml
#
# . Travel Restrictions and Quarantine Measures: Implement travel restrictions or quarantine measures in regions where the model predicts a surge in cases. Monitor the situation closely and adjust restrictions based on real-time data and model updates.
