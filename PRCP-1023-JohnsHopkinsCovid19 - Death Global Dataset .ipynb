# %% [markdown]
# ### PRCP-1023-JohnsHopkinsCovid19 - DEATH GLOBAL DATASET

# %% [markdown]
# ### TASK-1: Prepare a complete data analysis report on the given data.

# %%
## Importing librries
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
## loading the data
data=pd.read_csv('time_series_covid19_deaths_global.csv')

# %%
data
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110  67.709953        0
# 1              NaN             Albania  41.153300  20.168300        0
# 2              NaN             Algeria  28.033900   1.659600        0
# 3              NaN             Andorra  42.506300   1.521800        0
# 4              NaN              Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 261            NaN  West Bank and Gaza  31.952200  35.233200        0
# 262            NaN      Western Sahara  24.215500 -12.885800        0
# 263            NaN               Yemen  15.552727  48.516388        0
# 264            NaN              Zambia -13.133897  27.849332        0
# 265            NaN            Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  9/12/20  9/13/20  \
# ...

# %% [markdown]
# ### Data preprocessing :

# %%
data =data.drop(["Province/State","Lat","Long"],axis=1).groupby('Country/Region').sum()

# %%
data
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
Death_global=data.T

# %%
Death_global
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 1/22/20                   0        0        0        0       0
# 1/23/20                   0        0        0        0       0
# 1/24/20                   0        0        0        0       0
# 1/25/20                   0        0        0        0       0
# 1/26/20                   0        0        0        0       0
# ...                     ...      ...      ...      ...     ...
# 9/17/20                1436      347     1654       53     144
# 9/18/20                1437      353     1659       53     147
# 9/19/20                1437      358     1665       53     147
# 9/20/20                1441      362     1672       53     152
# 9/21/20                1444      364     1679       53     154
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 1/22/20                           0          0        0          0        0
# ...

# %% [markdown]
# ### Basic checks :

# %%
Death_global.head(5)
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 1/22/20                   0        0        0        0       0
# 1/23/20                   0        0        0        0       0
# 1/24/20                   0        0        0        0       0
# 1/25/20                   0        0        0        0       0
# 1/26/20                   0        0        0        0       0
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 1/22/20                           0          0        0          0        0
# 1/23/20                           0          0        0          0        0
# 1/24/20                           0          0        0          0        0
# 1/25/20                           0          0        0          0        0
# 1/26/20                           0          0        0          0        0
#
# Country/Region  ...  United Kingdom  Uruguay  Uzbekistan  Venezuela  Vietnam  \
# ...

# %%
Death_global.tail(5)
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 9/17/20                1436      347     1654       53     144
# 9/18/20                1437      353     1659       53     147
# 9/19/20                1437      358     1665       53     147
# 9/20/20                1441      362     1672       53     152
# 9/21/20                1444      364     1679       53     154
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 9/17/20                           3      12460      925        837      758
# 9/18/20                           3      12656      926        844      763
# 9/19/20                           3      12799      928        849      765
# 9/20/20                           3      13053      930        851      766
# 9/21/20                           3      13482      936        854      767
#
# Country/Region  ...  United Kingdom  Uruguay  Uzbekistan  Venezuela  Vietnam  \
# ...

# %%
Death_global.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, 1/22/20 to 9/21/20
# Columns: 188 entries, Afghanistan to Zimbabwe
# dtypes: int64(188)
# memory usage: 368.4+ KB

# %%
Death_global.describe()
# Out:
# Country/Region  Afghanistan     Albania      Algeria     Andorra      Angola  \
# count            244.000000  244.000000   244.000000  244.000000  244.000000
# mean             516.709016   82.643443   650.536885   34.327869   27.233607
# std              574.312759  105.049978   554.903531   22.766462   42.767901
# min                0.000000    0.000000     0.000000    0.000000    0.000000
# 25%                1.000000    3.500000    17.000000    1.000000    0.000000
# 50%              210.500000   31.000000   587.000000   51.000000    3.500000
# 75%             1195.250000  120.750000  1114.250000   52.000000   33.000000
# max             1444.000000  364.000000  1679.000000   53.000000  154.000000
#
# Country/Region  Antigua and Barbuda     Argentina     Armenia   Australia  \
# count                    244.000000    244.000000  244.000000  244.000000
# mean                       2.024590   2162.868852  305.258197  171.180328
# ...

# %%
Death_global.isnull().sum()
# Out:
# Country/Region
# Afghanistan           0
# Albania               0
# Algeria               0
# Andorra               0
# Angola                0
#                      ..
# West Bank and Gaza    0
# Western Sahara        0
# Yemen                 0
# Zambia                0
# Zimbabwe              0
# Length: 188, dtype: int64

# %% [markdown]
# ### We have selected main specific countries with COVID-confirmed from the original dataset :

# %%
specified_columns = ["Switzerland","South Africa","India","US","China","United Arab Emirates","Pakistan"]  # Example column names

selected_data = Death_global[specified_columns]
selected_data
# Out:
# Country/Region  Switzerland  South Africa  India      US  China  \
# 1/22/20                   0             0      0       0     17
# 1/23/20                   0             0      0       0     18
# 1/24/20                   0             0      0       0     26
# 1/25/20                   0             0      0       0     42
# 1/26/20                   0             0      0       0     56
# ...                     ...           ...    ...     ...    ...
# 9/17/20                2042         15772  84372  197633   4736
# 9/18/20                2045         15857  85619  198570   4737
# 9/19/20                2045         15940  86752  199282   4737
# 9/20/20                2045         15953  87882  199509   4737
# 9/21/20                2050         15992  87882  199865   4737
#
# Country/Region  United Arab Emirates  Pakistan
# 1/22/20                            0         0
# 1/23/20                            0         0
# 1/24/20                            0         0
# ...

# %%
selected_data.isnull().sum()
# Out:
# Country/Region
# Switzerland             0
# South Africa            0
# India                   0
# US                      0
# China                   0
# United Arab Emirates    0
# Pakistan                0
# dtype: int64

# %% [markdown]
# ### EDA :

# %%
for j in range(1,2):   
    plt.figure(figsize=(40,8))
    for tt in selected_data.columns[(j-1)*7:j*7]:
        Death_global = selected_data[[tt]]
        Death_global = Death_global[Death_global[tt]> 0].reset_index(drop=True)
        Death_global = Death_global.rolling(2).mean().fillna(0)
        plt.plot([str(i) for i in Death_global[tt].index],Death_global[tt],marker='*',label=tt)
        
    plt.title("COUNTRY LEVEL Death CASES GROWTH CURVE")
    plt.legend()
    plt.xlabel('Day')
    plt.ylabel('Death Cases')
    plt.show()

# %% [markdown]
# ### Autocorrelation :

# %%
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf

# Plot autocorrelation for each time series
for tt in selected_data.columns:
    Death_global = selected_data[[tt]]
    Death_global = Death_global[Death_global[tt] > 0].reset_index(drop=True)
    Death_global = Death_global.rolling(2).mean().fillna(0)
    
    plt.figure(figsize=(20, 10))
    plot_acf(Death_global[tt], lags=40)
    plt.title(f"Autocorrelation for {tt}")
    plt.xlabel('Lag')
    plt.ylabel('Autocorrelation')
    plt.show()

# %% [markdown]
# ### Check for Stationarity and Differencing :

# %%
# ADfuller Test to check stationarity
from statsmodels.tsa.stattools import adfuller
import numpy as np

for tt in selected_data.columns:
    Death_global = selected_data[[tt]]
    Death_global = Death_global[Death_global[tt] > 0].reset_index(drop=True)
    Death_global = Death_global.rolling(2).mean().fillna(0)
    
    result = adfuller(Death_global[tt])
    print(f'ADF Statistic for {tt}: {result[0]}')
    print(f'p-value for {tt}: {result[1]}')
# Out:
# ADF Statistic for Switzerland: -4.615933932875012
# p-value for Switzerland: 0.00012071080676006827
# ADF Statistic for South Africa: -2.861154461117334
# p-value for South Africa: 0.05005527318045853
# ADF Statistic for India: -0.6569628776210545
# p-value for India: 0.8575844977224919
# ADF Statistic for US: -2.0324110468312804
# p-value for US: 0.2725452326372516
# ADF Statistic for China: -4.1997657328453
# p-value for China: 0.0006595021068817479
# ADF Statistic for United Arab Emirates: -2.6646805022711506
# p-value for United Arab Emirates: 0.08035201659630331
# ADF Statistic for Pakistan: -2.2349517165597796
# p-value for Pakistan: 0.1938053695998278

# %% [markdown]
# ###

# %%
from statsmodels.graphics.tsaplots import plot_pacf

for tt in selected_data.columns:
    Death_global = selected_data[[tt]]
    Death_global = Death_global[Death_global[tt] > 0].reset_index(drop=True)
    Death_global = Death_global.rolling(2).mean().fillna(0)
    
    plt.figure(figsize=(20, 10))
    plot_acf(Death_global[tt], lags=40)
    plt.title(f"ACF for {tt}")
    plt.xlabel('Lag')
    plt.ylabel('Autocorrelation')
    plt.show()

    plt.figure(figsize=(20, 10))
    plot_pacf(Death_global[tt], lags=40)
    plt.title(f"PACF for {tt}")
    plt.xlabel('Lag')
    plt.ylabel('Partial Autocorrelation')
    plt.show()

# %% [markdown]
# ### Fit ARIMA Models and Select Best Model :

# %%
import statsmodels.api as sm

for tt in selected_data.columns:
    Death_global = selected_data[[tt]]
    Death_global = Death_global[Death_global[tt] > 0].reset_index(drop=True)
    Death_global = Death_global.rolling(2).mean().fillna(0)
    
    best_aic = np.inf
    best_order = None
    best_mdl = None
    
    for p in range(5):
        for d in range(2):
            for q in range(5):
                try:
                    tmp_mdl = sm.tsa.ARIMA(Death_global[tt], order=(p, d, q)).fit()
                    tmp_aic = tmp_mdl.aic
                    if tmp_aic < best_aic:
                        best_aic = tmp_aic
                        best_order = (p, d, q)
                        best_mdl = tmp_mdl
                except:
                    continue
    
    print(f"Best ARIMA{best_order} model for {tt} with AIC: {best_aic}")
    print(best_mdl.summary())
# Out:
# C:\Users\navee\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\navee\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\navee\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\navee\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...

# %% [markdown]
# ### Model Diagnostics :

# %%
for tt in selected_data.columns:
    Death_global = selected_data[[tt]]
    Death_global = Death_global[Death_global[tt] > 0].reset_index(drop=True)
    Death_global = Death_global.rolling(2).mean().fillna(0)
    
    model = sm.tsa.ARIMA(Death_global[tt], order=best_order)
    results = model.fit()
    
    residuals = results.resid
    
    plt.figure(figsize=(10, 5))
    plt.plot(residuals)
    plt.title(f'Residuals of the ARIMA model for {tt}')
    plt.show()
    
    plot_acf(residuals, lags=40)
    plt.title(f'Residuals ACF for {tt}')
    plt.show()
# Out:
# C:\Users\navee\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# ### Task -2 Forecasting :

# %%
for tt in selected_data.columns:
    Death_global = selected_data[[tt]]
    Death_global = Death_global[Death_global[tt] > 0].reset_index(drop=True)
    Death_global = Death_global.rolling(2).mean().fillna(0)
    
    model = sm.tsa.ARIMA(Death_global[tt], order=best_order)
    results = model.fit()
    
    forecast = results.forecast(steps=10)  # Example: forecast next 10 steps
    print(f"Forecast for {tt}:")
    print(forecast)
    
    plt.figure(figsize=(10, 5))
    plt.plot(Death_global[tt], label='Observed')
    plt.plot(range(len(Death_global), len(Death_global) + len(forecast)), forecast, label='Forecast')
    plt.legend()
    plt.title(f'Forecast for {tt}')
    plt.show()
# Out:
# Forecast for Switzerland:
# 201    2051.852890
# 202    2055.372754
# 203    2058.527942
# 204    2061.361140
# 205    2063.909706
# 206    2066.206361
# 207    2068.279774
# 208    2070.155090
# 209    2071.854373
# 210    2073.397001
# Name: predicted_mean, dtype: float64
# Forecast for South Africa:
# 179    16018.146379
# 180    16070.377104
# 181    16119.170439
# 182    16164.709230
# 183    16207.167691
# 184    16246.711778
# 185    16283.499547
# 186    16317.681497
# 187    16349.400902
# 188    16378.794126
# Name: predicted_mean, dtype: float64
# Forecast for India:
# 195    88343.537002
# 196    89251.938614
# 197    90157.540154
# 198    91062.266250
# 199    91966.015818
# 200    92868.795322
# 201    93770.605517
# 202    94671.447458
# 203    95571.322185
# 204    96470.230735
# Name: predicted_mean, dtype: float64
# Forecast for US:
# 206    200126.773189
# 207    200684.128771
# 208    201271.966927
# 209    201867.666352
# 210    202465.233884
# ...

# %% [markdown]
# ### Split the Data :

# %%
train_size = int(len(Death_global) * 0.8)
train, test = Death_global[:train_size], Death_global[train_size:]

# %% [markdown]
# ### Fit the Model on Training Set :

# %%
model = sm.tsa.ARIMA(train, order=best_order)
fitted_model = model.fit()

# %% [markdown]
# ### Make Predictions on the Test Set :

# %%
start = len(train)
end = len(train) + len(test) - 1
predictions = fitted_model.predict(start=start, end=end, typ='levels')

# %% [markdown]
# ### Calculate Accuracy Metrics :

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(test, predictions)
mse = mean_squared_error(test, predictions)
rmse = np.sqrt(mse)

print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Mean Absolute Error: 5.411696227324707
# Mean Squared Error: 43.777056131007555
# Root Mean Squared Error: 6.61642321280974

# %% [markdown]
# ### Task3 - Based on the predictions from your ARIMA model, you can make several suggestions to the government health department of the country/region for preparation. Here are some suggestions:
#
# - Resource Allocation: Allocate resources such as hospital beds, medical supplies, and personnel based on the forecasted number of COVID-19 cases.
# -
# Vaccine Distribution: Plan and execute the distribution of COVID-19 vaccines efficiently. Prioritize vaccination efforts based on the forecasted regions or demographic groups with the highest predicted case counts
#
# -
# Testing and Contact Tracing: Strengthen testing and contact tracing efforts in areas where the model predicts an increase in cases. Implement targeted testing strategies to identify and isolate infected individuals promptl
# - .
# Travel Restrictions and Quarantine Measures: Implement travel restrictions or quarantine measures in regions where the model predicts a surge in cases. Monitor the situation closely and adjust restrictions based on real-time data and model updates.
